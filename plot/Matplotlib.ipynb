# %% [markdown]
# # Data-Hub
# ## python assignment 05 - MatPlotLib
# ### Iman Salehi

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# q1

# %%
# According to my study, we have two options: first, adopt a theme for visualization, and second, seek professional counsel.
#
# In addition, I'm reading a SWD book that has been translated into Persian. I'm hoping I'll be able to discover a solution in it.
#
# 1. When working at close distances, use harmonic hues.
# 2. Experiment with saturation and lightening.
# 3. Use blue and warm hues.
# 4. It's critical to go green!
# 5. Stay away from pure hues.
# 6. Stay away from strong, intense colors.
# 7. Combine colors of varying lightness.
# 8. Don't use too little or too much contrast against the background.
# 9. Select a background that is sufficiently desaturated.
#
# reference:
# https://blog.datawrapper.de/colorguide/

# %% [markdown]
# q2

# %%
# scatter plot, -> Use a scatter plot to determine whether two variables have a relationship or correlation
# pie plot, -> trying to work out the composition of something. If you have categorical data then using a pie chart would work really well as each slice can represent a different category.
# histogram, -> Histograms are good for showing general distributional features of dataset variables
# count plot -> The seaborn countplot() function is used to display the number of observations in each categorical class using bars.

# %% [markdown]
# q3

# %%
# from matplotlib import pyplot
from matplotlib import style

style.use('ggplot')

x = [5, 8, 10]
y = [12, 16, 6]
x2 = [6, 9, ]  #  x2[2] removed!
y2 = [6, 15, ]

plt.plot(x, y, 'g', label='line one', linewidth=5)
plt.plot(x2, y2, 'c', label='line two', linewidth=5)
plt.title('Epic Info')
# plt.title('متن و عنوان فارسی')
# plt.title(('متن و عنوان فارسی')[::-1])
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.legend()
plt.grid(True, color='k')
plt.show()

# %%
# My search:
# persian text in matplotlib
# matplotlib rtl title

# The solution:
# https://medium.com/@amirashabani/pie-chart-and-persian-language-in-python-68dfd03a26fb

# Used sites:
# https://stackoverflow.com/
# https://gist.github.com/


from matplotlib import style

style.use('ggplot')

x = [5, 8, 10]
y = [12, 16, 6]
x2 = [6, 9, ]
y2 = [6, 15, ]

plt.plot(x, y, 'g', label='line one', linewidth=5)
plt.plot(x2, y2, 'c', label='line two', linewidth=5)

from bidi.algorithm import get_display
from arabic_reshaper import reshape

plt.title(get_display(reshape('متن و عنوان فارسی')))

plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.legend()
plt.grid(True, color='k')
plt.show()

# %% [markdown]
# q5

# %%
# as As far as I can tell, he wants a figure with some plots that are each a different color!
# There are six options! However, the majority of suggestions – 456 positive ratings – do not appear to be very beneficial.
# Also, the second response is insufficient, but I found the solution in the third answer that 'gboffi' mentioned.
# However, I feel that question is a little ambiguous.

my_colors = plt.rcParams['axes.prop_cycle']()  # <<< note that we CALL the prop_cycle
fig, axes = plt.subplots(2, 3)
for ax in axes.flatten(): ax.plot((0, 1), (0, 1), **next(my_colors))

# %% [markdown]
# q6

# %%
# Data:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

# MatPlotLib:
fig, ax = plt.subplots()
ax.pie(
    sizes,
    explode=explode,
    labels=labels,
    autopct='%1.1f%%',
    shadow=True,
    startangle=90
)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# Seaborn
import seaborn as sns

colors = sns.color_palette('pastel')[0:4]
plt.pie(
    sizes,
    explode=explode,
    labels=labels,
    autopct='%1.1f%%',
    shadow=True,
    startangle=90,
    colors=colors
)
plt.show()

# Conclusion:
# I previously preferred Seaborn,
# however after researching MatPlotLib vs SeaBorn, I discovered that Seaborn was the most recommended by features such as Functionality, Syntax, Use Cases, and so on.

# %% [markdown]
# q7

# %%
df = pd.DataFrame(
    columns=['year', 'package', 'rate'],
    data=[
        [2013, 'pandas', 0.1],
        [2014, 'pandas', 0.4],
        [2015, 'pandas', 0.6],
        [2016, 'pandas', 0.9],

        [2013, 'django', 0.1],
        [2014, 'django', 0.5],
        [2015, 'django', 0.3],
        [2016, 'django', 0.7]

    ]
)

ax = plt.gca()

for pack in df['package'].unique():
    x = df[df['package'] == pack]['year']
    y = df[df['package'] == pack]['rate']
    plt.plot(x, y, label=pack)

plt.xlabel('Year')
plt.ylabel('Rate')
plt.legend()

plt.show()

# %% [markdown]
# q8

# %%
fig = plt.figure()

ax1 = fig.add_subplot(131)
ax1.bar([1, 2, 3], [3, 4, 5])
ax1.axhline(3.5)

ax2 = fig.add_subplot(132)
ax2.barh([0.5, 1, 2.5], [0, 1, 2])
ax2.axvline(1.3)

ax3 = fig.add_subplot(133)
ax3.scatter(np.linspace(0, 1, 5), np.linspace(0, 5, 5))

fig.tight_layout()
plt.show()
